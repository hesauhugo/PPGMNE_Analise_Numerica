# %% [markdown]
# ## Exercício 9
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# $
# \mathit{Ax -b = (L+D+U)x^{k} -b} \\
# \mathit{-Dx^{k+1} + Ax^{k} -b = (L+U)x^{k} -b }\\
# \mathit{-Dx^{k+1} + Ax^{k} -b = x^{k}} \Rightarrow \mathit{-Dx^{k+1} = x^{k} - Ax^{k} + b } \Rightarrow \mathit{x^{k+1} =  x^{k} + D^{-1} (- Ax^{k} +b) }
# $
