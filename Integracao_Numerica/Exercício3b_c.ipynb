# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
 def f(x):
    return x**3 + 3*x**2 + 2*x -1

# %%
a=0
b=2
xx = np.linspace(a,b)
yy = xx**3 + 3*xx**2 + 2*xx -1
plt.plot(xx,yy,'r',label='f(x)')
plt.legend()

# %%
x = [0]*2
y = [0]*2
t = [0]*2
A = [1]*2
t[0] = -math.sqrt(3)/3
t[1]= math.sqrt(3)/3
x[0]=(1/2)*(((b-a)*t[0])+(a+b))
x[1]=(1/2)*(((b-a)*t[1])+(a+b))
y[0]=f(x[0])
y[1]=f(x[1])
print("A = ",A)
print("y = ",y)
print("x=",x)
# Out:
# A =  [1, 1]
# y =  [0.4566969491842414, 13.543303050815759]
# x= [0.42264973081037427, 1.5773502691896257]

# %%
I = ((b-a)/2)*(A[0]*y[0] + A[1]*y[1])
I
# Out:
# 14.0

# %%
from sympy  import *
init_printing(pretty_print=true)
z = Symbol('z')

# %%
e=Integral(z**3 + 3*z**2 + 2*z -1,(z,a,b)).doit().evalf()
e
# Out:
# 14.0000000000000

# %%
Erro = e-I
print("Erro = ",Erro)
print("% Erro = ",Erro/I*100)
# Out:
# Erro =  14.0 - I
# % Erro =  -100*I*(14.0 - I)

# %% [markdown]
# ### Questão 3 C

# %% [markdown]
# A questão anterior 3a não resultou em um resultado exato pois precisou ser combinado a regra de 1/3 e 3/8, já nessa questão 3b a regra da quadratura de gaus deu certa pois o grau do polinomio é de ordem 3 , sendo assim a regra garante a aproximação exata.
