# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import matplotlib.pyplot as plt
import math
import numpy as np

# %%
def f(x):
    return (x**2)*math.exp(-x**2)

# %%
def h(a,b,m):
    x = []
    y= []
    _h = (b-a)/m
    x.append(a)
    y.append(f(a))
    for i in range(1,m):
        a += _h
        x.append(a)
        y.append(f(a))
    x.append(b)
    y.append(f(b))
    return x,y

# %%
a=0
b=2
m=8
x,y = h(a,b,m)

# %%
xx = np.linspace(a,b)
yy = (xx**2)*np.exp(-xx**2)
plt.plot(x,y,'-',label='Trápezio')
plt.plot(xx,yy,'r',label='f(x)')
plt.legend()

# %%
def trapezioRepitida(x,a,b,m):
    h = (b-a)/m
    s = 0
    for i in range(1,m):
        s += f(x[i])
        print("i = ",i,"fx=",f(x[i]))
    v = (h/2)*(f(x[0]) + 2*s + f(x[m]))
    print("i=0",f(x[0]))
    print("i=m",f(x[m]))
    print("m = ",(m),"m =",m ,"x=",x,"h=",h)
    return v

# %%
tresult = trapezioRepitida(x,a,b,m)
tresult
# Out:
# i =  1 fx= 0.05871331642584224
# i =  2 fx= 0.19470019576785122
# i =  3 fx= 0.32050283891114417
# i =  4 fx= 0.36787944117144233
# i =  5 fx= 0.3275177924235903
# i =  6 fx= 0.23714825526419475
# i =  7 fx= 0.14323503105087437
# i=0 0.0
# i=m 0.07326255555493671
# m =  8 m = 8 x= [0, 0.25, 0.5, 0.75, 1.0, 1.25, 1.5, 1.75, 2] h= 0.25
# 0.42158203719810194

# %%
from sympy  import *
init_printing(pretty_print=true)
z = Symbol('z')

# %%
e = Integral((z**2)*exp(-z**2),(z,a,b)).doit().evalf()

# %%
Erro = e-tresult
print("Erro = ",Erro)
print("% Erro = ",Erro/tresult*100)
# Out:
# Erro =  0.00114301929437471
# % Erro =  0.271126185065045
